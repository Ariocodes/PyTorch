# %%
import torch
TENSOR = torch.rand(size=(3, 3, 4, 3))
TENSOR
# Out:
# tensor([[[[5.1800e-01, 8.5288e-02, 1.4919e-01],
#           [3.5226e-02, 3.9308e-01, 6.1320e-01],
#           [6.7727e-02, 1.9245e-01, 9.3859e-01],
#           [3.4579e-01, 9.5387e-01, 2.6465e-01]],
#
#          [[5.3025e-01, 3.9897e-01, 7.3465e-01],
#           [4.1022e-01, 7.5782e-01, 8.3474e-01],
#           [8.7867e-01, 4.5903e-02, 6.7741e-01],
#           [4.1502e-01, 2.7791e-01, 5.4818e-01]],
#
#          [[5.1603e-01, 3.6773e-01, 6.2644e-01],
#           [5.1818e-01, 3.2747e-04, 8.5344e-01],
#           [2.2813e-01, 9.6683e-02, 1.4247e-01],
#           [9.8915e-01, 5.7675e-01, 2.1360e-01]]],
#
#
#         [[[6.6376e-02, 2.5586e-01, 7.5960e-01],
#           [4.9396e-01, 8.4398e-01, 1.2127e-01],
#           [7.8918e-01, 2.6792e-01, 7.6239e-01],
#           [6.3611e-01, 7.4441e-01, 7.4312e-01]],
#
#          [[3.0086e-01, 6.9685e-01, 4.1097e-01],
#           [8.6827e-02, 4.1698e-01, 3.1782e-01],
#           [7.3394e-01, 4.5554e-01, 6.9191e-01],
# ...
